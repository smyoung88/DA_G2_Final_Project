# %%
import pandas as pd
file = "data_grouped_by_state.csv"
data = pd.read_csv(file)
data
# Out:
#                    State  Crash_Count_YAvg  Registered_Vehicles_Avg  \
# 0                Alabama       6501.666667             5.214827e+06
# 1               Arkansas        503.666667             2.850984e+06
# 2                Arizona      11582.333333             5.917769e+06
# 3             California     121013.000000             3.102158e+07
# 4               Colorado       8534.333333             5.342794e+06
# 5            Connecticut       4148.333333             2.861566e+06
# 6   District of Columbia        737.333333             3.494706e+05
# 7               Delaware        857.333333             9.987093e+05
# 8                Florida      38067.000000             1.742966e+07
# 9                Georgia      14606.000000             8.516481e+06
# 10                  Iowa       1677.000000             3.742766e+06
# 11                 Idaho        425.000000             1.890034e+06
# 12              Illinois      15841.333333             1.072387e+07
# ...

# %%
data = data[['State', 'Crash_Index_Weighted']]
data
# Out:
#                    State  Crash_Index_Weighted
# 0                Alabama              0.531660
# 1               Arkansas              0.142145
# 2                Arizona              0.527718
# 3             California              0.598258
# 4               Colorado              0.667646
# 5            Connecticut              0.250313
# 6   District of Columbia              0.134005
# 7               Delaware              0.191005
# 8                Florida              0.405258
# 9                Georgia              0.620893
# 10                  Iowa              0.330965
# 11                 Idaho              0.174148
# 12              Illinois              0.529150
# 13               Indiana              0.368949
# 14                Kansas              0.591862
# 15              Kentucky              0.366304
# 16             Louisiana              0.984804
# 17         Massachusetts              0.162197
# 18              Maryland              0.360350
# ...

# %%
data.to_csv('crash_index.csv')
