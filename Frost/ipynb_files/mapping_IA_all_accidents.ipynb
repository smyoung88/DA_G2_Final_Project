# %%
# Import dependencies
import pandas as pd

# %%
# Read the accidents CSV into Pandas DataFrame
accidents_data = pd.read_csv('../US_Accidents_Dec20_Updated.csv')
accidents_data.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         2  2019-05-21 08:29:55  2019-05-21 09:29:40  34.808868
# 1  A-2         2  2019-10-07 17:43:09  2019-10-07 19:42:50  35.090080
# 2  A-3         2  2020-12-13 21:53:00  2020-12-13 22:44:00  37.145730
# 3  A-4         2  2018-04-17 16:51:23  2018-04-17 17:50:46  39.110390
# 4  A-5         3  2016-08-31 17:40:49  2016-08-31 18:10:49  26.102942
#
#     Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0  -82.269157  34.808868  -82.269157           0.0
# 1  -80.745560  35.090080  -80.745560           0.0
# 2 -121.985052  37.165850 -121.988062           1.4
# 3 -119.773781  39.110390 -119.773781           0.0
# 4  -80.265091  26.102942  -80.265091           0.0
#
#                                          Description  ...  Roundabout Station  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.  ...       False   False
# 1  Accident on Houston Branch Rd at Providence Br...  ...       False   False
# 2  Stationary traffic on CA-17 from Summit Rd (CA...  ...       False   False
# 3         Accident on US-395 Southbound at Topsy Ln.  ...       False   False
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...  ...       False   False
#
#     Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0  False           False          False        False            Day
# 1  False           False          False        False            Day
# 2  False           False          False        False          Night
# 3  False           False           True        False            Day
# 4  False           False           True        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Day               Day                   Day
# 1            Day               Day                   Day
# 2          Night             Night                 Night
# 3            Day               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 47 columns]

# %%
accidents_data_dropped = accidents_data[['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'State', 'Number', 'Street', 'Description']]
accidents_data_dropped.head()
# Out:
#    Severity           Start_Time  Start_Lat   Start_Lng             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...

# %%
accidents_data_dropped.rename(columns={"Start_Time": "Date/Time", "Start_Lat": "Latitude", "Start_Lng": "Longitude"}, errors="raise", inplace=True)
accidents_data_dropped.head()
# Out:
# C:\Users\frost\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    Severity            Date/Time   Latitude   Longitude             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...

# %%
iowa_df = accidents_data_dropped.loc[accidents_data_dropped['State'] == "IA"]
iowa_df
# Out:
#          Severity            Date/Time   Latitude  Longitude             City  \
# 276             2  2018-10-25 18:40:51  41.597691 -93.718437  Windsor Heights
# 306             3  2017-10-19 06:57:28  41.877819 -93.571083        Cambridge
# 381             3  2017-01-16 02:48:13  41.493660 -94.237550           Dexter
# 589             2  2019-05-22 06:36:01  42.019909 -91.550224           Marion
# 787             2  2018-11-19 06:19:08  41.581806 -93.703514  West des Moines
# ...           ...                  ...        ...        ...              ...
# 2906034         2  2016-07-01 08:08:05  41.843000 -91.665620          Swisher
# 2906103         3  2019-10-18 09:39:35  41.126339 -92.410072          Ottumwa
# 2906280         2  2020-09-10 23:21:33  41.653536 -93.574429       Des Moines
# 2906297         3  2016-10-24 13:09:27  41.649185 -93.773880        Urbandale
# 2906358         2  2020-11-18 16:37:00  41.686429 -92.883343          Kellogg
#
#         State   Number       Street  \
# 276        IA   1036.0      73rd St
# 306        IA      NaN  Highway 210
# 381        IA      NaN       US-6 W
# 589        IA      NaN   Marion Byp
# 787        IA    844.0       1st St
# ...       ...      ...          ...
# 2906034    IA      NaN      IA-27 N
# 2906103    IA  16562.0  Highway 149
# 2906280    IA      NaN       I-80 W
# 2906297    IA      NaN       I-80 W
# 2906358    IA      NaN       I-80 E
#
#                                                Description
# 276                     Accident on 73rd St at Buffalo Rd.
# 306      Left lane blocked due to accident on I-35 Nort...
# 381                       At Adair Madison Ave - Accident.
# 589      Left lane blocked due to accident on US-151 So...
# 787              Accident on IA-28 63rd St near Grand Ave.
# ...                                                    ...
# 2906034  Between County Rd F-12/Exit 10 and IA-84/Wrigh...
# 2906103  Roadway reduced from two lanes to one lane due...
# 2906280  Incident on I-80 WB near EXIT 137A Expect long...
# 2906297  Entry ramp closed due to stalled vehicle on I-...
# 2906358  Slow traffic on I-80 E from IA-224/Exit 173 (I...
#
# [9492 rows x 9 columns]

# %%
iowa_df = iowa_df.round(decimals=4)
iowa_df.head()
# Out:
#      Severity            Date/Time  Latitude  Longitude             City  \
# 276         2  2018-10-25 18:40:51   41.5977   -93.7184  Windsor Heights
# 306         3  2017-10-19 06:57:28   41.8778   -93.5711        Cambridge
# 381         3  2017-01-16 02:48:13   41.4937   -94.2376           Dexter
# 589         2  2019-05-22 06:36:01   42.0199   -91.5502           Marion
# 787         2  2018-11-19 06:19:08   41.5818   -93.7035  West des Moines
#
#     State  Number       Street  \
# 276    IA  1036.0      73rd St
# 306    IA     NaN  Highway 210
# 381    IA     NaN       US-6 W
# 589    IA     NaN   Marion Byp
# 787    IA   844.0       1st St
#
#                                            Description
# 276                 Accident on 73rd St at Buffalo Rd.
# 306  Left lane blocked due to accident on I-35 Nort...
# 381                   At Adair Madison Ave - Accident.
# 589  Left lane blocked due to accident on US-151 So...
# 787          Accident on IA-28 63rd St near Grand Ave.

# %%
iowa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9492 entries, 276 to 2906358
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Severity     9492 non-null   int64
#  1   Date/Time    9492 non-null   object
#  2   Latitude     9492 non-null   float64
#  3   Longitude    9492 non-null   float64
#  4   City         9491 non-null   object
#  5   State        9492 non-null   object
#  6   Number       2396 non-null   float64
#  7   Street       9492 non-null   object
#  8   Description  9492 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 741.6+ KB

# %%
iowa_df['Number'] = iowa_df['Number'].fillna(0)

# %%
iowa_df['Number'] = iowa_df['Number'].map("{:.0f}".format)

# %%
iowa_df['Number'].replace({"0": ""}, inplace=True)

# %%
iowa_df.to_csv('../State_csv_files/Iowa.csv', encoding='UTF-8', index=False)
