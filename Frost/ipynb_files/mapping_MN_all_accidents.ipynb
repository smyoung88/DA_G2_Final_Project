# %%
# Import dependencies
import pandas as pd

# %%
# Read the accidents CSV into Pandas DataFrame
accidents_data = pd.read_csv('../US_Accidents_Dec20_Updated.csv')
accidents_data.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         2  2019-05-21 08:29:55  2019-05-21 09:29:40  34.808868
# 1  A-2         2  2019-10-07 17:43:09  2019-10-07 19:42:50  35.090080
# 2  A-3         2  2020-12-13 21:53:00  2020-12-13 22:44:00  37.145730
# 3  A-4         2  2018-04-17 16:51:23  2018-04-17 17:50:46  39.110390
# 4  A-5         3  2016-08-31 17:40:49  2016-08-31 18:10:49  26.102942
#
#     Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0  -82.269157  34.808868  -82.269157           0.0
# 1  -80.745560  35.090080  -80.745560           0.0
# 2 -121.985052  37.165850 -121.988062           1.4
# 3 -119.773781  39.110390 -119.773781           0.0
# 4  -80.265091  26.102942  -80.265091           0.0
#
#                                          Description  ...  Roundabout Station  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.  ...       False   False
# 1  Accident on Houston Branch Rd at Providence Br...  ...       False   False
# 2  Stationary traffic on CA-17 from Summit Rd (CA...  ...       False   False
# 3         Accident on US-395 Southbound at Topsy Ln.  ...       False   False
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...  ...       False   False
#
#     Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0  False           False          False        False            Day
# 1  False           False          False        False            Day
# 2  False           False          False        False          Night
# 3  False           False           True        False            Day
# 4  False           False           True        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Day               Day                   Day
# 1            Day               Day                   Day
# 2          Night             Night                 Night
# 3            Day               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 47 columns]

# %%
accidents_data_dropped = accidents_data[['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'State', 'Number', 'Street', 'Description']]
accidents_data_dropped.head()
# Out:
#    Severity           Start_Time  Start_Lat   Start_Lng             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...

# %%
accidents_data_dropped.rename(columns={"Start_Time": "Date/Time", "Start_Lat": "Latitude", "Start_Lng": "Longitude"}, errors="raise", inplace=True)
accidents_data_dropped.head()
# Out:
# C:\Users\frost\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    Severity            Date/Time   Latitude   Longitude             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...

# %%
minnesota_df = accidents_data_dropped.loc[accidents_data_dropped['State'] == "MN"]
minnesota_df
# Out:
#          Severity            Date/Time   Latitude  Longitude  \
# 47              2  2018-06-05 07:43:07  44.852409 -93.247139
# 53              2  2020-10-16 06:56:00  46.325429 -94.962033
# 83              2  2020-05-07 07:20:00  44.950750 -93.099340
# 91              2  2016-09-06 12:14:00  44.570877 -92.645325
# 114             2  2020-02-09 07:43:00  44.880010 -93.141150
# ...           ...                  ...        ...        ...
# 2906295         2  2020-06-24 23:44:00  44.874670 -93.060670
# 2906321         3  2017-08-03 08:10:02  44.952530 -93.082779
# 2906363         2  2019-02-05 17:37:11  45.079632 -93.717346
# 2906399         2  2020-01-17 06:05:49  44.573780 -93.298676
# 2906452         2  2020-07-17 07:47:27  46.587811 -94.309792
#
#                         City State   Number            Street  \
# 47               Minneapolis    MN      NaN           MN-77 N
# 53                   Aldrich    MN  47998.0         193rd Ave
# 83                Saint Paul    MN      NaN            I-94 E
# 91                  Red Wing    MN  32998.0   Highway 61 Blvd
# 114               Saint Paul    MN      NaN           I-35E S
# ...                      ...   ...      ...               ...
# 2906295  Inver Grove Heights    MN      NaN           I-494 E
# 2906321           Saint Paul    MN      NaN           US-10 E
# 2906363             Rockford    MN   7675.0  State Highway 55
# 2906399      Elko New Market    MN      NaN            I-35 S
# 2906452         Pequot Lakes    MN  29801.0       Patriot Ave
#
#                                                Description
# 47       Accident on MN-77 Southbound between I-494 and...
# 53       Incident on MN-210 near CR-77 Drive with caution.
# 83                           At I-35E/Exit 241 - Accident.
# 91                         At Cannon Bottom Rd - Accident.
# 114        Ramp to I-35E Southbound - Vehicle spun around.
# ...                                                    ...
# 2906295                       At US-52/Exit 66 - Accident.
# 2906321  Accident on I-94 Westbound between Exits 242D ...
# 2906363             Accident on MN-55 at CR-92 Dogwood St.
# 2906399      Accident on I-35 Southbound at CR-2 Deuce Rd.
# 2906452               Accident on Old Hwy 371 at Royce St.
#
# [79712 rows x 9 columns]

# %%
minnesota_df = minnesota_df.round(decimals=4)
minnesota_df.head()
# Out:
#      Severity            Date/Time  Latitude  Longitude         City State  \
# 47          2  2018-06-05 07:43:07   44.8524   -93.2471  Minneapolis    MN
# 53          2  2020-10-16 06:56:00   46.3254   -94.9620      Aldrich    MN
# 83          2  2020-05-07 07:20:00   44.9508   -93.0993   Saint Paul    MN
# 91          2  2016-09-06 12:14:00   44.5709   -92.6453     Red Wing    MN
# 114         2  2020-02-09 07:43:00   44.8800   -93.1412   Saint Paul    MN
#
#       Number            Street  \
# 47       NaN           MN-77 N
# 53   47998.0         193rd Ave
# 83       NaN            I-94 E
# 91   32998.0   Highway 61 Blvd
# 114      NaN           I-35E S
#
#                                            Description
# 47   Accident on MN-77 Southbound between I-494 and...
# 53   Incident on MN-210 near CR-77 Drive with caution.
# 83                       At I-35E/Exit 241 - Accident.
# 91                     At Cannon Bottom Rd - Accident.
# 114    Ramp to I-35E Southbound - Vehicle spun around.

# %%
minnesota_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79712 entries, 47 to 2906452
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Severity     79712 non-null  int64
#  1   Date/Time    79712 non-null  object
#  2   Latitude     79712 non-null  float64
#  3   Longitude    79712 non-null  float64
#  4   City         79710 non-null  object
#  5   State        79712 non-null  object
#  6   Number       19256 non-null  float64
#  7   Street       79712 non-null  object
#  8   Description  79712 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.1+ MB

# %%
minnesota_df['Number'] = minnesota_df['Number'].fillna(0)

# %%
minnesota_df['Number'] = minnesota_df['Number'].map("{:.0f}".format)

# %%
minnesota_df['Number'].replace({"0": ""}, inplace=True)

# %%
minnesota_df.to_csv('../State_csv_files/Minnesota.csv', encoding='UTF-8', index=False)
