# %%
# Import dependencies
import pandas as pd
import numpy as np
import json
import geojson

# %%
# Read the accidents CSV into Pandas DataFrame
accidents_data = pd.read_csv('../US_Accidents_Dec20_Updated.csv')
accidents_data.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         2  2019-05-21 08:29:55  2019-05-21 09:29:40  34.808868
# 1  A-2         2  2019-10-07 17:43:09  2019-10-07 19:42:50  35.090080
# 2  A-3         2  2020-12-13 21:53:00  2020-12-13 22:44:00  37.145730
# 3  A-4         2  2018-04-17 16:51:23  2018-04-17 17:50:46  39.110390
# 4  A-5         3  2016-08-31 17:40:49  2016-08-31 18:10:49  26.102942
#
#     Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0  -82.269157  34.808868  -82.269157           0.0
# 1  -80.745560  35.090080  -80.745560           0.0
# 2 -121.985052  37.165850 -121.988062           1.4
# 3 -119.773781  39.110390 -119.773781           0.0
# 4  -80.265091  26.102942  -80.265091           0.0
#
#                                          Description  ...  Roundabout Station  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.  ...       False   False
# ...

# %%
accidents_data_dropped = accidents_data[['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'State', 'Number', 'Street', 'Description']]
accidents_data_dropped.head()
# Out:
#    Severity           Start_Time  Start_Lat   Start_Lng             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# ...

# %%
accidents_data_dropped.rename(columns={"Start_Time": "Date/Time", "Start_Lat": "Latitude", "Start_Lng": "Longitude"}, errors="raise", inplace=True)
accidents_data_dropped.head()
# Out:
# C:\Users\frost\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    Severity            Date/Time   Latitude   Longitude             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# ...

# %%
california_df = accidents_data_dropped.loc[accidents_data_dropped['State'] == "CA"]
california_df.head()
# Out:
#     Severity            Date/Time   Latitude   Longitude         City State  \
# 2          2  2020-12-13 21:53:00  37.145730 -121.985052    Los Gatos    CA
# 7          2  2019-12-21 23:59:00  34.034017 -118.026972     Whittier    CA
# 9          2  2019-01-30 08:44:18  34.426330 -118.585100     Valencia    CA
# 16         2  2016-07-09 14:54:01  34.103172 -118.249969  Los Angeles    CA
# 17         2  2020-11-21 16:32:00  34.186595 -117.439427      Fontana    CA
#
#     Number              Street  \
# 2      NaN      Santa Cruz Hwy
# 7      NaN             CA-60 W
# 9      NaN  Golden State Fwy S
# 16     NaN              CA-2 S
# 17  3738.0          Sierra Ave
#
#                                           Description
# 2   Stationary traffic on CA-17 from Summit Rd (CA...
# 7                     At CA-60/Pomona Fwy - Accident.
# 9   At Magic Mountain Pky - Accident. Hard shoulde...
# 16        Accident on CA-2 Southbound at Exit 13 I-5.
# ...

# %%
california_sample_df = california_df.sample(2000)
california_sample_df.head()
# Out:
#          Severity            Date/Time   Latitude   Longitude     City State  \
# 228966          2  2017-09-04 09:30:03  34.052155 -117.717728   Pomona    CA
# 1505558         2  2019-10-22 09:18:12  37.863491 -122.035759    Alamo    CA
# 2424395         2  2019-12-27 15:59:00  39.157704 -123.631820    Philo    CA
# 1022317         2  2020-05-29 15:36:00  33.854225 -117.790650  Anaheim    CA
# 230813          2  2020-04-04 22:12:00  37.535556 -122.075000  Fremont    CA
#
#           Number           Street  \
# 228966   11098.0       Kadota Ave
# 1505558      NaN          I-680 S
# 2424395      NaN      Highway 128
# 1022317      NaN   S Imperial Hwy
# 230813       NaN  Bayfront Expy W
#
#                                                Description
# 228966   Accident on Kadota Ave between Grand Ave and 9...
# 1505558  Accident on I-680 Southbound at Exit 43 Livorn...
# 2424395                  At Boonville Ukiah Rd - Accident.
# ...

# %%
california_sample_df = california_sample_df.round(decimals=4)
california_sample_df.head()
# Out:
#          Severity            Date/Time  Latitude  Longitude     City State  \
# 228966          2  2017-09-04 09:30:03   34.0522  -117.7177   Pomona    CA
# 1505558         2  2019-10-22 09:18:12   37.8635  -122.0358    Alamo    CA
# 2424395         2  2019-12-27 15:59:00   39.1577  -123.6318    Philo    CA
# 1022317         2  2020-05-29 15:36:00   33.8542  -117.7906  Anaheim    CA
# 230813          2  2020-04-04 22:12:00   37.5356  -122.0750  Fremont    CA
#
#           Number           Street  \
# 228966   11098.0       Kadota Ave
# 1505558      NaN          I-680 S
# 2424395      NaN      Highway 128
# 1022317      NaN   S Imperial Hwy
# 230813       NaN  Bayfront Expy W
#
#                                                Description
# 228966   Accident on Kadota Ave between Grand Ave and 9...
# 1505558  Accident on I-680 Southbound at Exit 43 Livorn...
# 2424395                  At Boonville Ukiah Rd - Accident.
# 1022317                  At CA-90/Imperial Hwy - Accident.
# ...

# %%
california_sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 228966 to 830998
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Severity     2000 non-null   int64
#  1   Date/Time    2000 non-null   object
#  2   Latitude     2000 non-null   float64
#  3   Longitude    2000 non-null   float64
#  4   City         2000 non-null   object
#  5   State        2000 non-null   object
#  6   Number       474 non-null    float64
#  7   Street       2000 non-null   object
#  8   Description  2000 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 156.2+ KB

# %%
california_sample_df['Number'] = california_sample_df['Number'].fillna(0)

# %%
california_sample_df['Number'] = california_sample_df['Number'].map("{:.0f}".format)

# %%
california_sample_df['Number'].replace({"0": ""}, inplace=True)

# %%
california_sample_df.reset_index(drop=True, inplace=True)
california_sample_df.head()
# Out:
#    Severity            Date/Time  Latitude  Longitude     City State Number  \
# 0         2  2017-09-04 09:30:03   34.0522  -117.7177   Pomona    CA  11098
# 1         2  2019-10-22 09:18:12   37.8635  -122.0358    Alamo    CA
# 2         2  2019-12-27 15:59:00   39.1577  -123.6318    Philo    CA
# 3         2  2020-05-29 15:36:00   33.8542  -117.7906  Anaheim    CA
# 4         2  2020-04-04 22:12:00   37.5356  -122.0750  Fremont    CA
#
#             Street                                        Description
# 0       Kadota Ave  Accident on Kadota Ave between Grand Ave and 9...
# 1          I-680 S  Accident on I-680 Southbound at Exit 43 Livorn...
# 2      Highway 128                  At Boonville Ukiah Rd - Accident.
# 3   S Imperial Hwy                  At CA-90/Imperial Hwy - Accident.
# 4  Bayfront Expy W            At Dumbarton Brg Toll Plaza - Accident.

# %%
california_sample_df.to_csv('../State_sample_csv/California_sample.csv', encoding='UTF-8', index=False)
