# %%
# Import dependencies
import pandas as pd
import numpy as np
import json
import geojson

# %%
# Read the accidents CSV into Pandas DataFrame
accidents_data = pd.read_csv('US_Accidents_Dec20_Updated.csv')
accidents_data.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         2  2019-05-21 08:29:55  2019-05-21 09:29:40  34.808868
# 1  A-2         2  2019-10-07 17:43:09  2019-10-07 19:42:50  35.090080
# 2  A-3         2  2020-12-13 21:53:00  2020-12-13 22:44:00  37.145730
# 3  A-4         2  2018-04-17 16:51:23  2018-04-17 17:50:46  39.110390
# 4  A-5         3  2016-08-31 17:40:49  2016-08-31 18:10:49  26.102942
#
#     Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0  -82.269157  34.808868  -82.269157           0.0
# 1  -80.745560  35.090080  -80.745560           0.0
# 2 -121.985052  37.165850 -121.988062           1.4
# 3 -119.773781  39.110390 -119.773781           0.0
# 4  -80.265091  26.102942  -80.265091           0.0
#
#                                          Description  ...  Roundabout Station  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.  ...       False   False
# ...

# %%
accidents_data['Severity'].value_counts()
# Out:
# 2    2129263
# 3     629452
# 4     119144
# 1      28751
# Name: Severity, dtype: int64

# %%
sample_df = accidents_data.sample(n=1000)

# %%
sample_df.head()
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 1814087  A-1814088         2  2018-08-12 21:06:41  2018-08-12 21:36:14
# 155010    A-155011         3  2016-07-21 16:24:58  2016-07-21 22:24:58
# 2181071  A-2181072         2  2018-11-23 09:14:19  2018-11-23 09:43:42
# 2046389  A-2046390         2  2020-01-17 15:08:00  2020-01-17 15:42:20
# 2021493  A-2021494         2  2019-03-19 08:59:05  2019-03-19 09:58:39
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 1814087  35.841045  -78.611794  35.841045  -78.611794         0.000
# 155010   42.239620  -88.000370  42.254770  -88.020430         1.466
# 2181071  47.542450 -122.304190  47.551750 -122.316660         0.867
# 2046389  44.951360  -93.025220  44.951360  -93.025220         0.000
# 2021493  39.265755  -76.666931  39.265755  -76.666931         0.000
#
#                                                Description  ...  Roundabout  \
# ...

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1814087 to 2325583
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     1000 non-null   object
#  1   Severity               1000 non-null   int64
#  2   Start_Time             1000 non-null   object
#  3   End_Time               1000 non-null   object
#  4   Start_Lat              1000 non-null   float64
#  5   Start_Lng              1000 non-null   float64
#  6   End_Lat                898 non-null    float64
#  7   End_Lng                898 non-null    float64
#  8   Distance(mi)           1000 non-null   float64
#  9   Description            1000 non-null   object
#  10  Number                 355 non-null    float64
#  11  Street                 1000 non-null   object
#  12  Side                   1000 non-null   object
#  13  City                   1000 non-null   object
# ...

# %%
# new = accidents_data.loc[(accidents_data['Severity'] == 1)]
# new.head()

# %%
accidents_data = accidents_data.round(decimals=4)
accidents_data.head()

# %%
accidents_data.info()

# %%
empty = new.loc[new['City'] == "NaN"]
empty

# null_columns = new.columns[new.isnull().any()]
# new[null_columns].isnull().sum

# %%
accidents_data=accidents_data[accidents_data['City'].notna()]
accidents_data.head()

# %%
new_df.info()

# %%
print(new[new['City'].isnull()][null_columns])

# %%
new.info()

# %%
def data2geojson(sample_df):
    features = []
    insert_features = lambda X: features.append(
            geojson.Feature(geometry=geojson.Point((X["Start_Lng"],
                                                    X["Start_Lat"])),
                            properties=dict(datetime=X["Start_Time"],
                                            severity=X["Severity"],
                                            city=X["City"],
                                            state=X["State"],
                                            description=X["Description"])))
    sample_df.apply(insert_features, axis=1)
    with open('USA_all_accidents_sample.geojson', 'w', encoding='utf8') as fp:
        geojson.dump(geojson.FeatureCollection(features), fp, sort_keys=True, ensure_ascii=False)


data2geojson(sample_df)

# %%
sample_df
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 1814087  A-1814088         2  2018-08-12 21:06:41  2018-08-12 21:36:14
# 155010    A-155011         3  2016-07-21 16:24:58  2016-07-21 22:24:58
# 2181071  A-2181072         2  2018-11-23 09:14:19  2018-11-23 09:43:42
# 2046389  A-2046390         2  2020-01-17 15:08:00  2020-01-17 15:42:20
# 2021493  A-2021494         2  2019-03-19 08:59:05  2019-03-19 09:58:39
# ...            ...       ...                  ...                  ...
# 2087502  A-2087503         2  2017-07-24 08:36:32  2017-07-24 14:36:32
# 1110596  A-1110597         2  2020-04-08 16:51:55  2020-04-08 17:26:53
# 1090061  A-1090062         3  2019-05-27 13:52:23  2019-05-27 14:36:51
# 70086      A-70087         2  2019-07-10 05:02:13  2019-07-10 06:34:23
# 2325583  A-2325584         2  2020-12-13 23:42:07  2020-12-14 00:49:32
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# ...

# %%
sample_df.to_csv('sample_df.csv')
