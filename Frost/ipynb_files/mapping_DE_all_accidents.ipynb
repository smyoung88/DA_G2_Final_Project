# %%
# Import dependencies
import pandas as pd

# %%
# Read the accidents CSV into Pandas DataFrame
accidents_data = pd.read_csv('../US_Accidents_Dec20_Updated.csv')
accidents_data.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         2  2019-05-21 08:29:55  2019-05-21 09:29:40  34.808868
# 1  A-2         2  2019-10-07 17:43:09  2019-10-07 19:42:50  35.090080
# 2  A-3         2  2020-12-13 21:53:00  2020-12-13 22:44:00  37.145730
# 3  A-4         2  2018-04-17 16:51:23  2018-04-17 17:50:46  39.110390
# 4  A-5         3  2016-08-31 17:40:49  2016-08-31 18:10:49  26.102942
#
#     Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0  -82.269157  34.808868  -82.269157           0.0
# 1  -80.745560  35.090080  -80.745560           0.0
# 2 -121.985052  37.165850 -121.988062           1.4
# 3 -119.773781  39.110390 -119.773781           0.0
# 4  -80.265091  26.102942  -80.265091           0.0
#
#                                          Description  ...  Roundabout Station  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.  ...       False   False
# 1  Accident on Houston Branch Rd at Providence Br...  ...       False   False
# 2  Stationary traffic on CA-17 from Summit Rd (CA...  ...       False   False
# 3         Accident on US-395 Southbound at Topsy Ln.  ...       False   False
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...  ...       False   False
#
#     Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0  False           False          False        False            Day
# 1  False           False          False        False            Day
# 2  False           False          False        False          Night
# 3  False           False           True        False            Day
# 4  False           False           True        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Day               Day                   Day
# 1            Day               Day                   Day
# 2          Night             Night                 Night
# 3            Day               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 47 columns]

# %%
accidents_data_dropped = accidents_data[['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'State', 'Number', 'Street', 'Description']]
accidents_data_dropped.head()
# Out:
#    Severity           Start_Time  Start_Lat   Start_Lng             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...

# %%
accidents_data_dropped.rename(columns={"Start_Time": "Date/Time", "Start_Lat": "Latitude", "Start_Lng": "Longitude"}, errors="raise", inplace=True)
accidents_data_dropped.head()
# Out:
# C:\Users\frost\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    Severity            Date/Time   Latitude   Longitude             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...

# %%
delaware_df = accidents_data_dropped.loc[accidents_data_dropped['State'] == "DE"]
delaware_df
# Out:
#          Severity            Date/Time   Latitude  Longitude        City  \
# 2354            2  2017-08-31 13:15:45  39.744122 -75.562294  Wilmington
# 4063            4  2020-10-29 19:11:00  39.767877 -75.536976  Wilmington
# 4354            2  2019-08-14 07:23:31  39.723190 -75.606300  Wilmington
# 4478            2  2019-11-19 14:38:01  39.738701 -75.563873  Wilmington
# 4530            2  2020-10-18 23:30:30  39.710773 -75.592188  New Castle
# ...           ...                  ...        ...        ...         ...
# 2905514         3  2018-10-10 11:39:12  39.766785 -75.543129  Wilmington
# 2905530         2  2017-11-30 17:59:32  39.452644 -75.686371  Middletown
# 2905594         2  2018-12-20 18:10:51  39.532296 -75.649089  Middletown
# 2905674         2  2020-11-07 06:18:00  39.685202 -75.707012      Newark
# 2906527         4  2018-11-19 21:21:27  39.617852 -75.644133  New Castle
#
#         State  Number          Street  \
# 2354       DE   301.0  N Van Buren St
# 4063       DE     NaN          I-95 N
# 4354       DE   516.0    Rochelle Ave
# 4478       DE   508.0    Maryland Ave
# 4530       DE     NaN          I-95 S
# ...       ...     ...             ...
# 2905514    DE     NaN          I-95 N
# 2905530    DE     NaN   Brick Mill Rd
# 2905594    DE  1983.0     Dupont Pkwy
# 2905674    DE     NaN          DE-273
# 2906527    DE   913.0     Red Lion Rd
#
#                                                Description
# 2354     Accident on 3rd St both ways from Cherry St to...
# 4063     Incident on I-95 NB near SB THE Road closed. T...
# 4354               Accident on Rochelle Ave at Fallon Ave.
# 4478     Accident on DE-4 Maryland Ave Northbound at Ma...
# 4530     Stationary traffic on I-95 from DE-4/Maryland ...
# ...                                                    ...
# 2905514  Right lane closed due to accident on I-95 Sout...
# 2905530  Accident on DE-299 Middletown Odessa Rd at Bri...
# 2905594       At New Castle - Accident. Left lane blocked.
# 2905674  Incident on DE-273 EB near BALA RD Road closed...
# 2906527  Closed between US-301/US-40/Pulaski Hwy and SR...
#
# [4625 rows x 9 columns]

# %%
delaware_df = delaware_df.round(decimals=4)
delaware_df.head()
# Out:
#       Severity            Date/Time  Latitude  Longitude        City State  \
# 2354         2  2017-08-31 13:15:45   39.7441   -75.5623  Wilmington    DE
# 4063         4  2020-10-29 19:11:00   39.7679   -75.5370  Wilmington    DE
# 4354         2  2019-08-14 07:23:31   39.7232   -75.6063  Wilmington    DE
# 4478         2  2019-11-19 14:38:01   39.7387   -75.5639  Wilmington    DE
# 4530         2  2020-10-18 23:30:30   39.7108   -75.5922  New Castle    DE
#
#       Number          Street  \
# 2354   301.0  N Van Buren St
# 4063     NaN          I-95 N
# 4354   516.0    Rochelle Ave
# 4478   508.0    Maryland Ave
# 4530     NaN          I-95 S
#
#                                             Description
# 2354  Accident on 3rd St both ways from Cherry St to...
# 4063  Incident on I-95 NB near SB THE Road closed. T...
# 4354            Accident on Rochelle Ave at Fallon Ave.
# 4478  Accident on DE-4 Maryland Ave Northbound at Ma...
# 4530  Stationary traffic on I-95 from DE-4/Maryland ...

# %%
delaware_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4625 entries, 2354 to 2906527
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Severity     4625 non-null   int64
#  1   Date/Time    4625 non-null   object
#  2   Latitude     4625 non-null   float64
#  3   Longitude    4625 non-null   float64
#  4   City         4625 non-null   object
#  5   State        4625 non-null   object
#  6   Number       2569 non-null   float64
#  7   Street       4625 non-null   object
#  8   Description  4625 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 361.3+ KB

# %%
delaware_df['Number'] = delaware_df['Number'].fillna(0)

# %%
delaware_df['Number'] = delaware_df['Number'].map("{:.0f}".format)

# %%
delaware_df['Number'].replace({"0": ""}, inplace=True)

# %%
delaware_df.to_csv('../State_csv_files/Delaware.csv', encoding='UTF-8', index=False)
