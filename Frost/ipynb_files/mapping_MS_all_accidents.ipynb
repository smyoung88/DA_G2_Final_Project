# %%
# Import dependencies
import pandas as pd

# %%
# Read the accidents CSV into Pandas DataFrame
accidents_data = pd.read_csv('../US_Accidents_Dec20_Updated.csv')
accidents_data.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         2  2019-05-21 08:29:55  2019-05-21 09:29:40  34.808868
# 1  A-2         2  2019-10-07 17:43:09  2019-10-07 19:42:50  35.090080
# 2  A-3         2  2020-12-13 21:53:00  2020-12-13 22:44:00  37.145730
# 3  A-4         2  2018-04-17 16:51:23  2018-04-17 17:50:46  39.110390
# 4  A-5         3  2016-08-31 17:40:49  2016-08-31 18:10:49  26.102942
#
#     Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0  -82.269157  34.808868  -82.269157           0.0
# 1  -80.745560  35.090080  -80.745560           0.0
# 2 -121.985052  37.165850 -121.988062           1.4
# 3 -119.773781  39.110390 -119.773781           0.0
# 4  -80.265091  26.102942  -80.265091           0.0
#
#                                          Description  ...  Roundabout Station  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.  ...       False   False
# 1  Accident on Houston Branch Rd at Providence Br...  ...       False   False
# 2  Stationary traffic on CA-17 from Summit Rd (CA...  ...       False   False
# 3         Accident on US-395 Southbound at Topsy Ln.  ...       False   False
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...  ...       False   False
#
#     Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0  False           False          False        False            Day
# 1  False           False          False        False            Day
# 2  False           False          False        False          Night
# 3  False           False           True        False            Day
# 4  False           False           True        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Day               Day                   Day
# 1            Day               Day                   Day
# 2          Night             Night                 Night
# 3            Day               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 47 columns]

# %%
accidents_data_dropped = accidents_data[['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'State', 'Number', 'Street', 'Description']]
accidents_data_dropped.head()
# Out:
#    Severity           Start_Time  Start_Lat   Start_Lng             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...

# %%
accidents_data_dropped.rename(columns={"Start_Time": "Date/Time", "Start_Lat": "Latitude", "Start_Lng": "Longitude"}, errors="raise", inplace=True)
accidents_data_dropped.head()
# Out:
# C:\Users\frost\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    Severity            Date/Time   Latitude   Longitude             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...

# %%
mississippi_df = accidents_data_dropped.loc[accidents_data_dropped['State'] == "MS"]
mississippi_df
# Out:
#          Severity            Date/Time   Latitude  Longitude          City  \
# 174             2  2020-01-02 18:38:49  34.405780 -88.920700  Blue Springs
# 1038            3  2018-09-13 07:44:43  32.354412 -90.644264     Vicksburg
# 1105            2  2019-09-04 09:31:58  32.276020 -90.179000      Richland
# 1323            2  2018-11-18 21:34:34  31.666757 -90.456341    Brookhaven
# 2091            2  2020-08-10 07:13:00  34.346020 -89.521187        Oxford
# ...           ...                  ...        ...        ...           ...
# 2904985         2  2018-10-17 08:09:56  32.464680 -88.817688  Collinsville
# 2905111         2  2018-05-11 07:20:22  31.319262 -89.328308   Hattiesburg
# 2905303         2  2020-12-10 02:36:00  31.273586 -89.287994   Hattiesburg
# 2906147         2  2017-08-02 11:29:27  34.347305 -89.521156        Oxford
# 2906265         2  2020-11-14 01:18:00  30.466391 -88.419147    Moss Point
#
#         State  Number          Street  \
# 174        MS     NaN          I-22 W
# 1038       MS     NaN          I-20 W
# 1105       MS     NaN         US-49 S
# 1323       MS     NaN          I-55 N
# 2091       MS  2405.0    S Lamar Blvd
# ...       ...     ...             ...
# 2904985    MS  8224.0    Highway 19 N
# 2905111    MS  6051.0   US Highway 49
# 2905303    MS  5277.0   US Highway 49
# 2906147    MS  2377.0    S Lamar Blvd
# 2906265    MS     NaN          I-10 E
#
#                                                Description
# 174                     At MS-15/MS-30/Exit 64 - Accident.
# 1038            Accident on I-20 Westbound before Exit 15.
# 1105        At I-55/Exit 46 - Accident. Left lane blocked.
# 1323       At Mt Zion Rd/Exit 48 - Accident. Lane blocked.
# 2091                Accident on Lamar Blvd near Harlan Dr.
# ...                                                    ...
# 2904985  Right lane blocked due to accident on MS-19 No...
# 2905111  Left hand shoulder blocked due to accident on ...
# 2905303  Incident on US-49 SB near ELKS LAKE RD Right l...
# 2906147  Accident on Lamar Blvd Northbound near Belk Blvd.
# 2906265  Incident on I-10 EB near FRANKLIN CREEK RD Rig...
#
# [5419 rows x 9 columns]

# %%
mississippi_df = mississippi_df.round(decimals=4)
mississippi_df.head()
# Out:
#       Severity            Date/Time  Latitude  Longitude          City State  \
# 174          2  2020-01-02 18:38:49   34.4058   -88.9207  Blue Springs    MS
# 1038         3  2018-09-13 07:44:43   32.3544   -90.6443     Vicksburg    MS
# 1105         2  2019-09-04 09:31:58   32.2760   -90.1790      Richland    MS
# 1323         2  2018-11-18 21:34:34   31.6668   -90.4563    Brookhaven    MS
# 2091         2  2020-08-10 07:13:00   34.3460   -89.5212        Oxford    MS
#
#       Number        Street                                      Description
# 174      NaN        I-22 W               At MS-15/MS-30/Exit 64 - Accident.
# 1038     NaN        I-20 W       Accident on I-20 Westbound before Exit 15.
# 1105     NaN       US-49 S   At I-55/Exit 46 - Accident. Left lane blocked.
# 1323     NaN        I-55 N  At Mt Zion Rd/Exit 48 - Accident. Lane blocked.
# 2091  2405.0  S Lamar Blvd           Accident on Lamar Blvd near Harlan Dr.

# %%
mississippi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5419 entries, 174 to 2906265
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Severity     5419 non-null   int64
#  1   Date/Time    5419 non-null   object
#  2   Latitude     5419 non-null   float64
#  3   Longitude    5419 non-null   float64
#  4   City         5419 non-null   object
#  5   State        5419 non-null   object
#  6   Number       1184 non-null   float64
#  7   Street       5419 non-null   object
#  8   Description  5419 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 423.4+ KB

# %%
mississippi_df['Number'] = mississippi_df['Number'].fillna(0)

# %%
mississippi_df['Number'] = mississippi_df['Number'].map("{:.0f}".format)

# %%
mississippi_df['Number'].replace({"0": ""}, inplace=True)

# %%
mississippi_df.to_csv('../State_csv_files/Mississippi.csv', encoding='UTF-8', index=False)
