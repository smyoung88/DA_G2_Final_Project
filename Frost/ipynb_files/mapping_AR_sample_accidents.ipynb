# %%
# Import dependencies
import pandas as pd
import numpy as np
import json
import geojson

# %%
# Read the accidents CSV into Pandas DataFrame
accidents_data = pd.read_csv('../US_Accidents_Dec20_Updated.csv')
accidents_data.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         2  2019-05-21 08:29:55  2019-05-21 09:29:40  34.808868
# 1  A-2         2  2019-10-07 17:43:09  2019-10-07 19:42:50  35.090080
# 2  A-3         2  2020-12-13 21:53:00  2020-12-13 22:44:00  37.145730
# 3  A-4         2  2018-04-17 16:51:23  2018-04-17 17:50:46  39.110390
# 4  A-5         3  2016-08-31 17:40:49  2016-08-31 18:10:49  26.102942
#
#     Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0  -82.269157  34.808868  -82.269157           0.0
# 1  -80.745560  35.090080  -80.745560           0.0
# 2 -121.985052  37.165850 -121.988062           1.4
# 3 -119.773781  39.110390 -119.773781           0.0
# 4  -80.265091  26.102942  -80.265091           0.0
#
#                                          Description  ...  Roundabout Station  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.  ...       False   False
# ...

# %%
accidents_data_dropped = accidents_data[['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'State', 'Number', 'Street', 'Description']]
accidents_data_dropped.head()
# Out:
#    Severity           Start_Time  Start_Lat   Start_Lng             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# ...

# %%
accidents_data_dropped.rename(columns={"Start_Time": "Date/Time", "Start_Lat": "Latitude", "Start_Lng": "Longitude"}, errors="raise", inplace=True)
accidents_data_dropped.head()
# Out:
# C:\Users\frost\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    Severity            Date/Time   Latitude   Longitude             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# ...

# %%
arkansas_df = accidents_data_dropped.loc[accidents_data_dropped['State'] == "AR"]
arkansas_df.head()
# Out:
#       Severity                      Date/Time   Latitude  Longitude  \
# 793          2  2020-10-28 09:03:30.000000000  34.908939 -91.196554
# 912          2            2020-10-15 21:00:56  35.221835 -92.833131
# 1190         2            2020-11-09 16:48:15  33.822199 -91.471602
# 2192         2            2020-10-03 07:03:17  34.328472 -92.924313
# 2443         2            2020-11-24 00:07:40  35.252130 -92.387379
#
#             City State  Number             Street  \
# 793     Brinkley    AR     NaN             I-40 W
# 912       Atkins    AR     NaN             I-40 W
# 1190      Tillar    AR   101.0      Highway 159 E
# 2192   Donaldson    AR     NaN             I-30 W
# 2443  Greenbrier    AR     NaN  Blueberry Hill Ln
#
#                                             Description
# 793   Stationary traffic on I-40 from US-49/AR-17/Ex...
# 912    Incident on I-40 WB near I-40 Left lane blocked.
# 1190  Incident on US-65 NB near US-65 Left lane bloc...
# ...

# %%
arkansas_sample_df = arkansas_df.sample(2000)
arkansas_sample_df.head()
# Out:
#          Severity            Date/Time   Latitude  Longitude         City  \
# 432838          2  2018-12-17 07:42:16  33.614790 -92.772430       Camden
# 2028285         3  2019-10-24 14:24:16  35.771320 -94.187200      Winslow
# 1145044         4  2018-09-06 19:52:52  36.115984 -91.142743   Black Rock
# 1222132         2  2020-11-04 23:30:54  35.884362 -89.922569  Blytheville
# 1935677         4  2018-08-29 13:47:59  35.737480 -91.639050   Batesville
#
#         State  Number            Street  \
# 432838     AR  2435.0      Highway 79 N
# 2028285    AR     NaN            I-49 S
# 1145044    AR  4000.0        Highway 63
# 1222132    AR     NaN            I-55 S
# 1935677    AR   849.0   Batesville Blvd
#
#                                                Description
# 432838   At US-79/US-79-br/AR-4-br - Multi-vehicle acci...
# 2028285  At Washington/Crawford County Line - Accident....
# 1145044  Closed at US-62/Locust - Road closed due to ac...
# ...

# %%
arkansas_sample_df = arkansas_sample_df.round(decimals=4)
arkansas_sample_df.head()
# Out:
#          Severity            Date/Time  Latitude  Longitude         City  \
# 432838          2  2018-12-17 07:42:16   33.6148   -92.7724       Camden
# 2028285         3  2019-10-24 14:24:16   35.7713   -94.1872      Winslow
# 1145044         4  2018-09-06 19:52:52   36.1160   -91.1427   Black Rock
# 1222132         2  2020-11-04 23:30:54   35.8844   -89.9226  Blytheville
# 1935677         4  2018-08-29 13:47:59   35.7375   -91.6390   Batesville
#
#         State  Number            Street  \
# 432838     AR  2435.0      Highway 79 N
# 2028285    AR     NaN            I-49 S
# 1145044    AR  4000.0        Highway 63
# 1222132    AR     NaN            I-55 S
# 1935677    AR   849.0   Batesville Blvd
#
#                                                Description
# 432838   At US-79/US-79-br/AR-4-br - Multi-vehicle acci...
# 2028285  At Washington/Crawford County Line - Accident....
# 1145044  Closed at US-62/Locust - Road closed due to ac...
# ...

# %%
arkansas_sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 432838 to 2682869
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Severity     2000 non-null   int64
#  1   Date/Time    2000 non-null   object
#  2   Latitude     2000 non-null   float64
#  3   Longitude    2000 non-null   float64
#  4   City         2000 non-null   object
#  5   State        2000 non-null   object
#  6   Number       687 non-null    float64
#  7   Street       2000 non-null   object
#  8   Description  2000 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 156.2+ KB

# %%
arkansas_sample_df['Number'] = arkansas_sample_df['Number'].fillna(0)

# %%
arkansas_sample_df['Number'] = arkansas_sample_df['Number'].map("{:.0f}".format)

# %%
arkansas_sample_df['Number'].replace({"0": ""}, inplace=True)

# %%
arkansas_sample_df.reset_index(drop=True, inplace=True)
arkansas_sample_df.head()
# Out:
#    Severity            Date/Time  Latitude  Longitude         City State  \
# 0         2  2018-12-17 07:42:16   33.6148   -92.7724       Camden    AR
# 1         3  2019-10-24 14:24:16   35.7713   -94.1872      Winslow    AR
# 2         4  2018-09-06 19:52:52   36.1160   -91.1427   Black Rock    AR
# 3         2  2020-11-04 23:30:54   35.8844   -89.9226  Blytheville    AR
# 4         4  2018-08-29 13:47:59   35.7375   -91.6390   Batesville    AR
#
#   Number            Street                                        Description
# 0   2435      Highway 79 N  At US-79/US-79-br/AR-4-br - Multi-vehicle acci...
# 1                   I-49 S  At Washington/Crawford County Line - Accident....
# 2   4000        Highway 63  Closed at US-62/Locust - Road closed due to ac...
# 3                   I-55 S  Incident on I-55 SB near I-55 Right lane block...
# 4    849   Batesville Blvd       At Batesville Blvd - Accident. Lane blocked.

# %%
arkansas_sample_df.to_csv('../State_sample_csv/Arkansas_sample.csv', encoding='UTF-8', index=False)
