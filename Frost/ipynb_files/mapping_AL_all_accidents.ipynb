# %%
# Import dependencies
import pandas as pd

# %%
# Read the accidents CSV into Pandas DataFrame
accidents_data = pd.read_csv('../US_Accidents_Dec20_Updated.csv')
accidents_data.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         2  2019-05-21 08:29:55  2019-05-21 09:29:40  34.808868
# 1  A-2         2  2019-10-07 17:43:09  2019-10-07 19:42:50  35.090080
# 2  A-3         2  2020-12-13 21:53:00  2020-12-13 22:44:00  37.145730
# 3  A-4         2  2018-04-17 16:51:23  2018-04-17 17:50:46  39.110390
# 4  A-5         3  2016-08-31 17:40:49  2016-08-31 18:10:49  26.102942
#
#     Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0  -82.269157  34.808868  -82.269157           0.0
# 1  -80.745560  35.090080  -80.745560           0.0
# 2 -121.985052  37.165850 -121.988062           1.4
# 3 -119.773781  39.110390 -119.773781           0.0
# 4  -80.265091  26.102942  -80.265091           0.0
#
#                                          Description  ...  Roundabout Station  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.  ...       False   False
# 1  Accident on Houston Branch Rd at Providence Br...  ...       False   False
# 2  Stationary traffic on CA-17 from Summit Rd (CA...  ...       False   False
# 3         Accident on US-395 Southbound at Topsy Ln.  ...       False   False
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...  ...       False   False
#
#     Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0  False           False          False        False            Day
# 1  False           False          False        False            Day
# 2  False           False          False        False          Night
# 3  False           False           True        False            Day
# 4  False           False           True        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Day               Day                   Day
# 1            Day               Day                   Day
# 2          Night             Night                 Night
# 3            Day               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 47 columns]

# %%
accidents_data_dropped = accidents_data[['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'State', 'Number', 'Street', 'Description']]
accidents_data_dropped.head()
# Out:
#    Severity           Start_Time  Start_Lat   Start_Lng             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...

# %%
accidents_data_dropped.rename(columns={"Start_Time": "Date/Time", "Start_Lat": "Latitude", "Start_Lng": "Longitude"}, errors="raise", inplace=True)
accidents_data_dropped.head()
# Out:
# C:\Users\frost\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    Severity            Date/Time   Latitude   Longitude             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...

# %%
alabama_df = accidents_data_dropped.loc[accidents_data_dropped['State'] == "AL"]
alabama_df
# Out:
#          Severity            Date/Time   Latitude  Longitude        City  \
# 142             2  2019-08-15 12:43:53  34.753899 -86.740997     Madison
# 212             2  2019-10-24 21:52:29  33.494110 -86.330162    Cropwell
# 414             2  2017-09-07 16:13:15  30.877176 -88.044342     Satsuma
# 435             3  2018-06-26 17:34:42  33.411137 -86.970207    Bessemer
# 488             2  2019-05-17 10:46:48  34.739841 -86.662178  Huntsville
# ...           ...                  ...        ...        ...         ...
# 2906306         2  2020-09-17 23:40:30  30.738490 -88.110877      Mobile
# 2906350         2  2019-05-16 13:49:53  31.190481 -85.401558      Dothan
# 2906390         4  2020-11-07 01:10:00  33.402594 -86.977593    Bessemer
# 2906533         2  2018-05-09 20:50:16  32.980888 -86.689697     Jemison
# 2906573         2  2019-09-11 12:05:41  31.785810 -85.965050        Troy
#
#         State  Number              Street  \
# 142        AL     NaN           Hughes Rd
# 212        AL    84.0     Mount Pisgah Dr
# 414        AL     NaN          Highway 43
# 435        AL  1276.0           19th St N
# 488        AL     NaN  Old Monrovia Rd NW
# ...       ...     ...                 ...
# 2906306    AL     NaN              I-65 S
# 2906350    AL     NaN      Ross Clark Cir
# 2906390    AL     NaN              I-20 W
# 2906533    AL     NaN              I-65 S
# 2906573    AL   921.0       Highway 231 S
#
#                                                Description
# 142              Accident on US-72 Westbound at Hughes Rd.
# 212      Accident on US-231 Northbound at Mount Pisgah Dr.
# 414                             Accident on US-43 at I-65.
# 435      Accident on I-59 I-20 Southbound between Exit ...
# 488      Lane blocked due to accident on US-72 Universi...
# ...                                                    ...
# 2906306  Queuing traffic on I-65 from US-45/AL-17/Saint...
# 2906350  Lane blocked due to accident on US-231 Ross Cl...
# 2906390  Incident on I-20 WB near MM 110 Road closed. T...
# 2906533  Accident on exit ramp from I-65 Southbound at ...
# 2906573     At Highway 231 - Accident. Right lane blocked.
#
# [33290 rows x 9 columns]

# %%
alabama_df = alabama_df.round(decimals=4)
alabama_df.head()
# Out:
#      Severity            Date/Time  Latitude  Longitude        City State  \
# 142         2  2019-08-15 12:43:53   34.7539   -86.7410     Madison    AL
# 212         2  2019-10-24 21:52:29   33.4941   -86.3302    Cropwell    AL
# 414         2  2017-09-07 16:13:15   30.8772   -88.0443     Satsuma    AL
# 435         3  2018-06-26 17:34:42   33.4111   -86.9702    Bessemer    AL
# 488         2  2019-05-17 10:46:48   34.7398   -86.6622  Huntsville    AL
#
#      Number              Street  \
# 142     NaN           Hughes Rd
# 212    84.0     Mount Pisgah Dr
# 414     NaN          Highway 43
# 435  1276.0           19th St N
# 488     NaN  Old Monrovia Rd NW
#
#                                            Description
# 142          Accident on US-72 Westbound at Hughes Rd.
# 212  Accident on US-231 Northbound at Mount Pisgah Dr.
# 414                         Accident on US-43 at I-65.
# 435  Accident on I-59 I-20 Southbound between Exit ...
# 488  Lane blocked due to accident on US-72 Universi...

# %%
alabama_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33290 entries, 142 to 2906573
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Severity     33290 non-null  int64
#  1   Date/Time    33290 non-null  object
#  2   Latitude     33290 non-null  float64
#  3   Longitude    33290 non-null  float64
#  4   City         33290 non-null  object
#  5   State        33290 non-null  object
#  6   Number       11480 non-null  float64
#  7   Street       33290 non-null  object
#  8   Description  33290 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 2.5+ MB

# %%
alabama_df['Number'] = alabama_df['Number'].fillna(0)

# %%
alabama_df['Number'] = alabama_df['Number'].map("{:.0f}".format)

# %%
alabama_df['Number'].replace({"0": ""}, inplace=True)

# %%
alabama_df.reset_index(drop=True, inplace=True)
alabama_df.head()

# %%
alabama_df.to_csv('../State_sample_csv/Alabama.csv', encoding='UTF-8', index=False)
