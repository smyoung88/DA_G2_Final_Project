# %%
# Import dependencies
import pandas as pd

# %%
# Read the accidents CSV into Pandas DataFrame
accidents_data = pd.read_csv('../US_Accidents_Dec20_Updated.csv')
accidents_data.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         2  2019-05-21 08:29:55  2019-05-21 09:29:40  34.808868
# 1  A-2         2  2019-10-07 17:43:09  2019-10-07 19:42:50  35.090080
# 2  A-3         2  2020-12-13 21:53:00  2020-12-13 22:44:00  37.145730
# 3  A-4         2  2018-04-17 16:51:23  2018-04-17 17:50:46  39.110390
# 4  A-5         3  2016-08-31 17:40:49  2016-08-31 18:10:49  26.102942
#
#     Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0  -82.269157  34.808868  -82.269157           0.0
# 1  -80.745560  35.090080  -80.745560           0.0
# 2 -121.985052  37.165850 -121.988062           1.4
# 3 -119.773781  39.110390 -119.773781           0.0
# 4  -80.265091  26.102942  -80.265091           0.0
#
#                                          Description  ...  Roundabout Station  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.  ...       False   False
# 1  Accident on Houston Branch Rd at Providence Br...  ...       False   False
# 2  Stationary traffic on CA-17 from Summit Rd (CA...  ...       False   False
# 3         Accident on US-395 Southbound at Topsy Ln.  ...       False   False
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...  ...       False   False
#
#     Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0  False           False          False        False            Day
# 1  False           False          False        False            Day
# 2  False           False          False        False          Night
# 3  False           False           True        False            Day
# 4  False           False           True        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Day               Day                   Day
# 1            Day               Day                   Day
# 2          Night             Night                 Night
# 3            Day               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 47 columns]

# %%
accidents_data_dropped = accidents_data[['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'State', 'Number', 'Street', 'Description']]
accidents_data_dropped.head()
# Out:
#    Severity           Start_Time  Start_Lat   Start_Lng             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...

# %%
accidents_data_dropped.rename(columns={"Start_Time": "Date/Time", "Start_Lat": "Latitude", "Start_Lng": "Longitude"}, errors="raise", inplace=True)
accidents_data_dropped.head()
# Out:
# C:\Users\frost\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    Severity            Date/Time   Latitude   Longitude             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...

# %%
maryland_df = accidents_data_dropped.loc[accidents_data_dropped['State'] == "MD"]
maryland_df
# Out:
#          Severity            Date/Time   Latitude  Longitude  \
# 73              2  2017-05-10 15:53:49  38.864871 -76.846793
# 89              2  2020-11-07 20:20:30  38.384973 -75.422516
# 197             3  2020-05-10 19:41:21  39.262850 -76.566950
# 257             2  2020-07-22 13:40:40  39.327599 -77.582863
# 316             2  2019-10-22 14:15:53  39.187038 -77.169777
# ...           ...                  ...        ...        ...
# 2906344         3  2018-11-09 04:56:14  39.663700 -79.476700
# 2906365         2  2020-06-22 01:04:10  39.043070 -76.668820
# 2906432         2  2018-08-22 06:51:34  39.352345 -76.598564
# 2906585         2  2018-10-13 16:53:16  38.955147 -76.721092
# 2906603         2  2016-12-19 06:34:56  38.993397 -77.026680
#
#                        City State  Number                     Street  \
# 73          Capitol Heights    MD     NaN          Capital Beltway N
# 89               Pittsville    MD     NaN                 Ocean Gtwy
# 197               Baltimore    MD  4589.0                  Keith Ave
# 257               Knoxville    MD  3501.0            Olive School Rd
# 316      Montgomery Village    MD  8456.0              E Village Ave
# ...                     ...   ...     ...                        ...
# 2906344        Friendsville    MD     NaN                     I-68 W
# 2906365           Gambrills    MD   906.0   Saint Stephens Church Rd
# 2906432           Baltimore    MD  1199.0               Glenwood Ave
# 2906585               Bowie    MD     NaN          John Hanson Hwy W
# 2906603       Silver Spring    MD  8300.0                Georgia Ave
#
#                                                Description
# 73               At I-495/I-95/Capital Beltway - Accident.
# 89                             US 50 WEST AT SIXTY FOOT RD
# 197                                    At I-95 - Accident.
# 257      Accident on MD-464 Point Of Rocks Rd at Olive ...
# 316              Accident on Village Ave at Doubleland Rd.
# ...                                                    ...
# 2906344  At West Virginia/Maryland St Line - Accident. ...
# 2906365               At St Stephens Church Rd - Accident.
# 2906432           Accident on The Alameda at Glenwood Ave.
# 2906585  Entry ramp to US-50 Westbound from Crain Hwy S...
# 2906603      Accident on Bonifant St at US-29 Georgia Ave.
#
# [52755 rows x 9 columns]

# %%
maryland_df = maryland_df.round(decimals=4)
maryland_df.head()
# Out:
#      Severity            Date/Time  Latitude  Longitude                City  \
# 73          2  2017-05-10 15:53:49   38.8649   -76.8468     Capitol Heights
# 89          2  2020-11-07 20:20:30   38.3850   -75.4225          Pittsville
# 197         3  2020-05-10 19:41:21   39.2628   -76.5670           Baltimore
# 257         2  2020-07-22 13:40:40   39.3276   -77.5829           Knoxville
# 316         2  2019-10-22 14:15:53   39.1870   -77.1698  Montgomery Village
#
#     State  Number             Street  \
# 73     MD     NaN  Capital Beltway N
# 89     MD     NaN         Ocean Gtwy
# 197    MD  4589.0          Keith Ave
# 257    MD  3501.0    Olive School Rd
# 316    MD  8456.0      E Village Ave
#
#                                            Description
# 73           At I-495/I-95/Capital Beltway - Accident.
# 89                         US 50 WEST AT SIXTY FOOT RD
# 197                                At I-95 - Accident.
# 257  Accident on MD-464 Point Of Rocks Rd at Olive ...
# 316          Accident on Village Ave at Doubleland Rd.

# %%
maryland_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52755 entries, 73 to 2906603
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Severity     52755 non-null  int64
#  1   Date/Time    52755 non-null  object
#  2   Latitude     52755 non-null  float64
#  3   Longitude    52755 non-null  float64
#  4   City         52752 non-null  object
#  5   State        52755 non-null  object
#  6   Number       13236 non-null  float64
#  7   Street       52755 non-null  object
#  8   Description  52755 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 4.0+ MB

# %%
maryland_df['Number'] = maryland_df['Number'].fillna(0)

# %%
maryland_df['Number'] = maryland_df['Number'].map("{:.0f}".format)

# %%
maryland_df['Number'].replace({"0": ""}, inplace=True)

# %%
maryland_df.to_csv('../State_csv_files/Maryland.csv', encoding='UTF-8', index=False)
