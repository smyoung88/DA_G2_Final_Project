# %%
# Import dependencies
import pandas as pd
import numpy as np
import json
import geojson

# %%
# Read the accidents CSV into Pandas DataFrame
accidents_data = pd.read_csv('../US_Accidents_Dec20_Updated.csv')
accidents_data.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         2  2019-05-21 08:29:55  2019-05-21 09:29:40  34.808868
# 1  A-2         2  2019-10-07 17:43:09  2019-10-07 19:42:50  35.090080
# 2  A-3         2  2020-12-13 21:53:00  2020-12-13 22:44:00  37.145730
# 3  A-4         2  2018-04-17 16:51:23  2018-04-17 17:50:46  39.110390
# 4  A-5         3  2016-08-31 17:40:49  2016-08-31 18:10:49  26.102942
#
#     Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0  -82.269157  34.808868  -82.269157           0.0
# 1  -80.745560  35.090080  -80.745560           0.0
# 2 -121.985052  37.165850 -121.988062           1.4
# 3 -119.773781  39.110390 -119.773781           0.0
# 4  -80.265091  26.102942  -80.265091           0.0
#
#                                          Description  ...  Roundabout Station  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.  ...       False   False
# ...

# %%
accidents_data_dropped = accidents_data[['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'State', 'Number', 'Street', 'Description']]
accidents_data_dropped.head()
# Out:
#    Severity           Start_Time  Start_Lat   Start_Lng             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# ...

# %%
accidents_data_dropped.rename(columns={"Start_Time": "Date/Time", "Start_Lat": "Latitude", "Start_Lng": "Longitude"}, errors="raise", inplace=True)
accidents_data_dropped.head()
# Out:
# C:\Users\frost\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    Severity            Date/Time   Latitude   Longitude             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# ...

# %%
alabama_df = accidents_data_dropped.loc[accidents_data_dropped['State'] == "AL"]
alabama_df.head()
# Out:
#      Severity            Date/Time   Latitude  Longitude        City State  \
# 142         2  2019-08-15 12:43:53  34.753899 -86.740997     Madison    AL
# 212         2  2019-10-24 21:52:29  33.494110 -86.330162    Cropwell    AL
# 414         2  2017-09-07 16:13:15  30.877176 -88.044342     Satsuma    AL
# 435         3  2018-06-26 17:34:42  33.411137 -86.970207    Bessemer    AL
# 488         2  2019-05-17 10:46:48  34.739841 -86.662178  Huntsville    AL
#
#      Number              Street  \
# 142     NaN           Hughes Rd
# 212    84.0     Mount Pisgah Dr
# 414     NaN          Highway 43
# 435  1276.0           19th St N
# 488     NaN  Old Monrovia Rd NW
#
#                                            Description
# 142          Accident on US-72 Westbound at Hughes Rd.
# 212  Accident on US-231 Northbound at Mount Pisgah Dr.
# 414                         Accident on US-43 at I-65.
# 435  Accident on I-59 I-20 Southbound between Exit ...
# ...

# %%
alabama_sample_df = alabama_df.sample(2000)
alabama_sample_df.head()
# Out:
#          Severity            Date/Time   Latitude  Longitude         City  \
# 725307          2  2018-10-03 09:10:44  33.413330 -86.809030   Birmingham
# 1848632         2  2020-11-14 10:05:00  32.192033 -86.419197  Letohatchee
# 975885          2  2020-12-03 17:47:00  32.304650 -86.337663   Montgomery
# 1170416         2  2020-10-28 15:03:00  34.631127 -86.870646      Madison
# 2081974         2  2018-04-10 17:06:45  30.570847 -88.171509     Theodore
#
#         State  Number      Street  \
# 725307     AL     NaN      I-65 S
# 1848632    AL     NaN      I-65 S
# 975885     AL     NaN      I-65 S
# 1170416    AL     NaN     AL-20 W
# 2081974    AL  5626.0  Highway 90
#
#                                                Description
# 725307   At US-31/Montgomery Hwy/Exit 252 - Accident. R...
# 1848632  Incident on I-65 SB near MM 157 Road closed. T...
# 975885   Incident on I-65 SB near MM 166 Right shoulder...
# 1170416      Incident on I-565 WB near MM 0 Expect delays.
# ...

# %%
alabama_sample_df = alabama_sample_df.round(decimals=4)
alabama_sample_df.head()
# Out:
#          Severity            Date/Time  Latitude  Longitude         City  \
# 725307          2  2018-10-03 09:10:44   33.4133   -86.8090   Birmingham
# 1848632         2  2020-11-14 10:05:00   32.1920   -86.4192  Letohatchee
# 975885          2  2020-12-03 17:47:00   32.3046   -86.3377   Montgomery
# 1170416         2  2020-10-28 15:03:00   34.6311   -86.8706      Madison
# 2081974         2  2018-04-10 17:06:45   30.5708   -88.1715     Theodore
#
#         State  Number      Street  \
# 725307     AL     NaN      I-65 S
# 1848632    AL     NaN      I-65 S
# 975885     AL     NaN      I-65 S
# 1170416    AL     NaN     AL-20 W
# 2081974    AL  5626.0  Highway 90
#
#                                                Description
# 725307   At US-31/Montgomery Hwy/Exit 252 - Accident. R...
# 1848632  Incident on I-65 SB near MM 157 Road closed. T...
# 975885   Incident on I-65 SB near MM 166 Right shoulder...
# 1170416      Incident on I-565 WB near MM 0 Expect delays.
# ...

# %%
alabama_sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 725307 to 2830354
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Severity     2000 non-null   int64
#  1   Date/Time    2000 non-null   object
#  2   Latitude     2000 non-null   float64
#  3   Longitude    2000 non-null   float64
#  4   City         2000 non-null   object
#  5   State        2000 non-null   object
#  6   Number       710 non-null    float64
#  7   Street       2000 non-null   object
#  8   Description  2000 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 156.2+ KB

# %%
alabama_sample_df['Number'] = alabama_sample_df['Number'].fillna(0)

# %%
alabama_sample_df['Number'] = alabama_sample_df['Number'].map("{:.0f}".format)

# %%
alabama_sample_df['Number'].replace({"0": ""}, inplace=True)

# %%
alabama_sample_df.reset_index(drop=True, inplace=True)
alabama_sample_df.head()
# Out:
#    Severity            Date/Time  Latitude  Longitude         City State  \
# 0         2  2018-10-03 09:10:44   33.4133   -86.8090   Birmingham    AL
# 1         2  2020-11-14 10:05:00   32.1920   -86.4192  Letohatchee    AL
# 2         2  2020-12-03 17:47:00   32.3046   -86.3377   Montgomery    AL
# 3         2  2020-10-28 15:03:00   34.6311   -86.8706      Madison    AL
# 4         2  2018-04-10 17:06:45   30.5708   -88.1715     Theodore    AL
#
#   Number      Street                                        Description
# 0             I-65 S  At US-31/Montgomery Hwy/Exit 252 - Accident. R...
# 1             I-65 S  Incident on I-65 SB near MM 157 Road closed. T...
# 2             I-65 S  Incident on I-65 SB near MM 166 Right shoulder...
# 3            AL-20 W      Incident on I-565 WB near MM 0 Expect delays.
# 4   5626  Highway 90  Accident on US-90 from Kooiman Rd to Larue Ste...

# %%
alabama_sample_df.to_csv('../State_sample_csv/Alabama_sample.csv', encoding='UTF-8', index=False)
