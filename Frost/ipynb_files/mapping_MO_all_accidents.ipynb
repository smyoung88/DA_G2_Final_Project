# %%
# Import dependencies
import pandas as pd

# %%
# Read the accidents CSV into Pandas DataFrame
accidents_data = pd.read_csv('../US_Accidents_Dec20_Updated.csv')
accidents_data.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         2  2019-05-21 08:29:55  2019-05-21 09:29:40  34.808868
# 1  A-2         2  2019-10-07 17:43:09  2019-10-07 19:42:50  35.090080
# 2  A-3         2  2020-12-13 21:53:00  2020-12-13 22:44:00  37.145730
# 3  A-4         2  2018-04-17 16:51:23  2018-04-17 17:50:46  39.110390
# 4  A-5         3  2016-08-31 17:40:49  2016-08-31 18:10:49  26.102942
#
#     Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0  -82.269157  34.808868  -82.269157           0.0
# 1  -80.745560  35.090080  -80.745560           0.0
# 2 -121.985052  37.165850 -121.988062           1.4
# 3 -119.773781  39.110390 -119.773781           0.0
# 4  -80.265091  26.102942  -80.265091           0.0
#
#                                          Description  ...  Roundabout Station  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.  ...       False   False
# 1  Accident on Houston Branch Rd at Providence Br...  ...       False   False
# 2  Stationary traffic on CA-17 from Summit Rd (CA...  ...       False   False
# 3         Accident on US-395 Southbound at Topsy Ln.  ...       False   False
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...  ...       False   False
#
#     Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0  False           False          False        False            Day
# 1  False           False          False        False            Day
# 2  False           False          False        False          Night
# 3  False           False           True        False            Day
# 4  False           False           True        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Day               Day                   Day
# 1            Day               Day                   Day
# 2          Night             Night                 Night
# 3            Day               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 47 columns]

# %%
accidents_data_dropped = accidents_data[['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'State', 'Number', 'Street', 'Description']]
accidents_data_dropped.head()
# Out:
#    Severity           Start_Time  Start_Lat   Start_Lng             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...

# %%
accidents_data_dropped.rename(columns={"Start_Time": "Date/Time", "Start_Lat": "Latitude", "Start_Lng": "Longitude"}, errors="raise", inplace=True)
accidents_data_dropped.head()
# Out:
# C:\Users\frost\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    Severity            Date/Time   Latitude   Longitude             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...

# %%
missouri_df = accidents_data_dropped.loc[accidents_data_dropped['State'] == "MO"]
missouri_df
# Out:
#          Severity            Date/Time   Latitude  Longitude         City  \
# 101             3  2018-12-15 07:15:13  37.010113 -94.548073       Joplin
# 225             2  2020-10-06 10:18:28  38.938068 -94.398103  Lees Summit
# 349             4  2020-01-08 12:08:49  39.079310 -94.490730  Kansas City
# 386             3  2020-11-20 17:20:15  38.743896 -90.412605    Bridgeton
# 424             3  2019-02-13 04:40:52  39.020229 -94.175552    Oak Grove
# ...           ...                  ...        ...        ...          ...
# 2905833         3  2020-05-19 22:15:10  39.000780 -94.357210  Lees Summit
# 2905976         2  2017-08-30 19:59:21  38.117710 -91.319290     Leasburg
# 2906316         2  2016-09-01 08:16:20  38.936390 -94.451150  Kansas City
# 2906417         3  2019-12-24 15:14:09  38.568050 -90.393707  Saint Louis
# 2906563         2  2017-09-28 07:28:26  37.214817 -93.270874  Springfield
#
#         State  Number                 Street  \
# 101        MO     NaN                 I-44 W
# 225        MO     NaN                I-470 W
# 349        MO     NaN                I-435 N
# 386        MO     NaN  Saint Charles Rock Rd
# 424        MO     NaN                 I-70 W
# ...       ...     ...                    ...
# 2905833    MO     NaN                I-470 S
# 2905976    MO     NaN                 I-44 E
# 2906316    MO     NaN                I-470 E
# 2906417    MO     NaN            Big Bend Rd
# 2906563    MO     NaN          N Fremont Ave
#
#                                                Description
# 101      Left lane closed due to accident on I-44 Eastb...
# 225      Incident on I-470 WB near MO-350 Right lane bl...
# 349      Closed at MO-78/23rd St/Exit 61 - Road closed ...
# 386      Left lane closed due to accident on I-70 Westb...
# 424      Left lane blocked due to multi-vehicle acciden...
# ...                                                    ...
# 2905833  At NE Woods Chapel Rd/Exit 12 - Accident. Righ...
# 2905976  Between MO-H/Exit 214 and MO-C/Exit 218 - Acci...
# 2906316                 At View High Dr/Exit 5 - Accident.
# 2906417  Center lane closed due to accident on I-44 Wes...
# 2906563          Accident on Chestnut Expy at Fremont Ave.
#
# [28674 rows x 9 columns]

# %%
missouri_df = missouri_df.round(decimals=4)
missouri_df.head()
# Out:
#      Severity            Date/Time  Latitude  Longitude         City State  \
# 101         3  2018-12-15 07:15:13   37.0101   -94.5481       Joplin    MO
# 225         2  2020-10-06 10:18:28   38.9381   -94.3981  Lees Summit    MO
# 349         4  2020-01-08 12:08:49   39.0793   -94.4907  Kansas City    MO
# 386         3  2020-11-20 17:20:15   38.7439   -90.4126    Bridgeton    MO
# 424         3  2019-02-13 04:40:52   39.0202   -94.1756    Oak Grove    MO
#
#      Number                 Street  \
# 101     NaN                 I-44 W
# 225     NaN                I-470 W
# 349     NaN                I-435 N
# 386     NaN  Saint Charles Rock Rd
# 424     NaN                 I-70 W
#
#                                            Description
# 101  Left lane closed due to accident on I-44 Eastb...
# 225  Incident on I-470 WB near MO-350 Right lane bl...
# 349  Closed at MO-78/23rd St/Exit 61 - Road closed ...
# 386  Left lane closed due to accident on I-70 Westb...
# 424  Left lane blocked due to multi-vehicle acciden...

# %%
missouri_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28674 entries, 101 to 2906563
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Severity     28674 non-null  int64
#  1   Date/Time    28674 non-null  object
#  2   Latitude     28674 non-null  float64
#  3   Longitude    28674 non-null  float64
#  4   City         28674 non-null  object
#  5   State        28674 non-null  object
#  6   Number       3512 non-null   float64
#  7   Street       28674 non-null  object
#  8   Description  28674 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 2.2+ MB

# %%
missouri_df['Number'] = missouri_df['Number'].fillna(0)

# %%
missouri_df['Number'] = missouri_df['Number'].map("{:.0f}".format)

# %%
missouri_df['Number'].replace({"0": ""}, inplace=True)

# %%
missouri_df.to_csv('../State_csv_files/Missouri.csv', encoding='UTF-8', index=False)
