# %%
# Import dependencies
import pandas as pd

# %%
# Read the accidents CSV into Pandas DataFrame
accidents_data = pd.read_csv('../US_Accidents_Dec20_Updated.csv')
accidents_data.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         2  2019-05-21 08:29:55  2019-05-21 09:29:40  34.808868
# 1  A-2         2  2019-10-07 17:43:09  2019-10-07 19:42:50  35.090080
# 2  A-3         2  2020-12-13 21:53:00  2020-12-13 22:44:00  37.145730
# 3  A-4         2  2018-04-17 16:51:23  2018-04-17 17:50:46  39.110390
# 4  A-5         3  2016-08-31 17:40:49  2016-08-31 18:10:49  26.102942
#
#     Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0  -82.269157  34.808868  -82.269157           0.0
# 1  -80.745560  35.090080  -80.745560           0.0
# 2 -121.985052  37.165850 -121.988062           1.4
# 3 -119.773781  39.110390 -119.773781           0.0
# 4  -80.265091  26.102942  -80.265091           0.0
#
#                                          Description  ...  Roundabout Station  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.  ...       False   False
# ...

# %%
accidents_data_dropped = accidents_data[['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'State', 'Number', 'Street', 'Description']]
accidents_data_dropped.head()
# Out:
#    Severity           Start_Time  Start_Lat   Start_Lng             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# 4    FL     NaN               I-595 W
#
#                                          Description
# 0            Accident on Tanner Rd at Pennbrooke Ln.
# 1  Accident on Houston Branch Rd at Providence Br...
# 2  Stationary traffic on CA-17 from Summit Rd (CA...
# 3         Accident on US-395 Southbound at Topsy Ln.
# ...

# %%
accidents_data_dropped.rename(columns={"Start_Time": "Date/Time", "Start_Lat": "Latitude", "Start_Lng": "Longitude"}, errors="raise", inplace=True)
accidents_data_dropped.head()
# Out:
# C:\Users\frost\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    Severity            Date/Time   Latitude   Longitude             City  \
# 0         2  2019-05-21 08:29:55  34.808868  -82.269157       Greenville
# 1         2  2019-10-07 17:43:09  35.090080  -80.745560        Charlotte
# 2         2  2020-12-13 21:53:00  37.145730 -121.985052        Los Gatos
# 3         2  2018-04-17 16:51:23  39.110390 -119.773781      Carson City
# 4         3  2016-08-31 17:40:49  26.102942  -80.265091  Fort Lauderdale
#
#   State  Number                Street  \
# 0    SC   439.0             Tanner Rd
# 1    NC  3299.0  Providence Branch Ln
# 2    CA     NaN        Santa Cruz Hwy
# 3    NV     NaN      US Highway 395 S
# ...

# %%
massachusetts_df = accidents_data_dropped.loc[accidents_data_dropped['State'] == "MA"]
massachusetts_df
# Out:
#          Severity            Date/Time   Latitude  Longitude  \
# 155             2  2020-05-17 16:45:17  42.430195 -71.103012
# 157             1  2020-06-20 02:44:37  41.958900 -71.063670
# 305             3  2017-03-23 16:26:25  42.167667 -71.937218
# 448             3  2020-03-23 17:54:24  42.245310 -71.199000
# 547             2  2018-01-07 13:10:34  42.212754 -71.148947
# ...           ...                  ...        ...        ...
# 2905945         2  2020-06-10 10:58:34  42.242760 -70.995920
# 2906153         2  2017-03-15 06:07:08  42.700758 -70.967621
# 2906288         3  2020-02-24 11:51:00  42.156017 -72.791985
# 2906294         2  2020-04-17 13:48:24  42.331530 -71.254440
# 2906389         2  2018-08-30 08:08:21  42.457596 -70.949982
#
#                        City State  Number       Street  \
# 155                 Medford    MA     NaN       I-93 N
# 157                 Raynham    MA     NaN      I-495 N
# 305                Charlton    MA     NaN       I-90 E
# ...

# %%
massachusetts_df = massachusetts_df.round(decimals=4)
massachusetts_df.head()
# Out:
#      Severity            Date/Time  Latitude  Longitude      City State  \
# 155         2  2020-05-17 16:45:17   42.4302   -71.1030   Medford    MA
# 157         1  2020-06-20 02:44:37   41.9589   -71.0637   Raynham    MA
# 305         3  2017-03-23 16:26:25   42.1677   -71.9372  Charlton    MA
# 448         3  2020-03-23 17:54:24   42.2453   -71.1990    Dedham    MA
# 547         2  2018-01-07 13:10:34   42.2128   -71.1489    Dedham    MA
#
#      Number    Street                                        Description
# 155     NaN    I-93 N  Accident on I-93 Northbound at Exit 33 MA-28 F...
# 157     NaN   I-495 N  Between RT-24/Exit 7 and Bay St/Exit 9 - Accid...
# 305     NaN    I-90 E  Two lanes blocked due to accident on I-90 East...
# 448     NaN   High St  Ramp to RT-109/High St Eastbound - Vehicle spu...
# 547     NaN  MA-128 N                           At Canton St - Accident.

# %%
massachusetts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25121 entries, 155 to 2906389
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Severity     25121 non-null  int64
#  1   Date/Time    25121 non-null  object
#  2   Latitude     25121 non-null  float64
#  3   Longitude    25121 non-null  float64
#  4   City         25121 non-null  object
#  5   State        25121 non-null  object
#  6   Number       8041 non-null   float64
#  7   Street       25121 non-null  object
#  8   Description  25121 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 1.9+ MB

# %%
massachusetts_df['Number'] = massachusetts_df['Number'].fillna(0)

# %%
massachusetts_df['Number'] = massachusetts_df['Number'].map("{:.0f}".format)

# %%
massachusetts_df['Number'].replace({"0": ""}, inplace=True)

# %%
massachusetts_df.to_csv('../State_csv_files/Massachusetts.csv', encoding='UTF-8', index=False)
