# %%
import pandas as pd
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
interstates = pd.read_csv('resources/all_us_interstates.csv') 
highways = pd.read_csv('resources/all_us_highways.csv')

# %%
interstates.head()
# Out:
#                full_name state_name  \
# 0                  I- 10    Alabama
# 1                  I- 10    Alabama
# 2                  I- 10    Alabama
# 3                  I- 10    Alabama
# 4  I- 10 Industrial Pkwy    Alabama
#
#                                            road_geom
# 0  LINESTRING(-87.412165 30.573765, -87.412276 30...
# 1  LINESTRING(-88.40047 30.474213, -88.399619 30....
# 2  LINESTRING(-88.007269 30.686598, -88.005754 30...
# 3  LINESTRING(-88.40049 30.474455, -88.399889 30....
# 4  LINESTRING(-88.174432 30.568621, -88.174352 30...

# %%
highways.head()
# Out:
#            full_name state_name  \
# 0  US 98 Frontage Rd    Alabama
# 1   US Forest Svc Rd    Alabama
# 2   US Government Rd    Alabama
# 3   US Government Rd    Alabama
# 4          US Hwy 10    Alabama
#
#                                            road_geom
# 0  LINESTRING(-87.912731 30.64539, -87.912816 30....
# 1  LINESTRING(-87.379328 34.097353, -87.379332 34...
# 2  LINESTRING(-85.106533 31.64339, -85.106493 31....
# 3  LINESTRING(-85.113503 31.643839, -85.113289 31...
# 4  LINESTRING(-88.295371 32.170564, -88.295732 32...

# %%
import math

# %%
def get_distance(dataset):
    
    output = []
    for i in dataset['road_geom'].to_list():
        i = i.replace('LINESTRING(','')[:-1]
        f = [[float(h) for h in j.split()] for j in i.split(',')]

        output.append(list(f))
            
    dataset['road_geom'] = output
        
    
    sums = []
    for i in dataset['road_geom'].to_list():
    
        
        each_road = 0

        last_coord = i[0]
        for j in i[1:]:
            distance = math.sqrt(((last_coord[0]-j[0])**2)+((last_coord[1]-j[1])**2))
            last_coord = j

            each_road += distance
        sums.append(each_road)
    
    dataset['geo_points'] = [len(i) for i in dataset['road_geom']]
    dataset['distance'] = sums
    return dataset

# %%
interstates = get_distance(interstates)

# %%
interstates.head()
# Out:
#                full_name state_name  \
# 0                  I- 10    Alabama
# 1                  I- 10    Alabama
# 2                  I- 10    Alabama
# 3                  I- 10    Alabama
# 4  I- 10 Industrial Pkwy    Alabama
#
#                                            road_geom  geo_points  distance
# 0  [[-87.412165, 30.573765], [-87.412276, 30.5737...         385  0.619295
# 1  [[-88.40047, 30.474213], [-88.399619, 30.47454...         386  0.466148
# 2  [[-88.007269, 30.686598], [-88.005754, 30.6861...         373  0.619205
# 3  [[-88.40049, 30.474455], [-88.399889, 30.47469...         363  0.466335
# 4  [[-88.174432, 30.568621], [-88.174352, 30.5685...           9  0.002690

# %%
highways = get_distance(highways)

# %%
highways.head()
# Out:
#            full_name state_name  \
# 0  US 98 Frontage Rd    Alabama
# 1   US Forest Svc Rd    Alabama
# 2   US Government Rd    Alabama
# 3   US Government Rd    Alabama
# 4          US Hwy 10    Alabama
#
#                                            road_geom  geo_points  distance
# 0  [[-87.912731, 30.64539], [-87.912816, 30.64543...          21  0.006994
# 1  [[-87.379328, 34.097353], [-87.379332, 34.0978...          11  0.010345
# 2  [[-85.106533, 31.64339], [-85.106493, 31.64318...           7  0.002469
# 3  [[-85.113503, 31.643839], [-85.113289, 31.6438...          17  0.007466
# 4  [[-88.295371, 32.170564], [-88.295732, 32.1706...           5  0.001346

# %%
interstate_distance = interstates.groupby(['state_name']).sum()['distance'].reset_index().rename(columns = {'distance':'sum_interstate_distance'})
interstate_distance.head()
# Out:
#    state_name  sum_interstate_distance
# 0     Alabama                36.236478
# 1     Arizona                39.706072
# 2    Arkansas                24.131938
# 3  California                81.544651
# 4    Colorado                34.757985

# %%
highway_distance = highways.groupby(['state_name']).sum()['distance'].reset_index().rename(columns = {'distance':'sum_highway_distance'})
highway_distance.head()
# Out:
#    state_name  sum_highway_distance
# 0     Alabama             84.315171
# 1      Alaska              0.002441
# 2     Arizona             37.897351
# 3    Arkansas             86.258683
# 4  California             46.537062

# %%
distance_by_state = interstate_distance.merge(highway_distance, how = 'outer', on = 'state_name').sort_values('state_name').reset_index(drop=True)
distance_by_state
# Out:
#               state_name  sum_interstate_distance  sum_highway_distance
# 0                Alabama                36.236478             84.315171
# 1                 Alaska                      NaN              0.002441
# 2                Arizona                39.706072             37.897351
# 3               Arkansas                24.131938             86.258683
# 4             California                81.544651             46.537062
# 5               Colorado                34.757985            105.259867
# 6            Connecticut                11.909521             11.266595
# 7               Delaware                 1.390199              7.388483
# 8   District of Columbia                 0.396204              0.821816
# 9                Florida                46.610764            111.016011
# 10               Georgia                39.589953            124.396675
# 11                Hawaii                 1.703521                   NaN
# 12                 Idaho                22.591678             53.348266
# 13              Illinois                78.758617             79.947825
# 14               Indiana                49.600900             75.696967
# 15                  Iowa                27.209664             90.034701
# 16                Kansas                30.092208            124.566312
# 17              Kentucky                30.165558             79.844313
# 18             Louisiana                30.452238             58.436147
# 19                 Maine                12.170105             25.238616
# 20              Maryland                18.566393             25.862990
# 21         Massachusetts                19.258425             14.582594
# 22              Michigan                47.492773             63.907888
# 23             Minnesota                32.950938             93.214559
# 24           Mississippi                27.054475             69.973432
# 25              Missouri                47.723860            106.265560
# 26               Montana                45.173852             74.956553
# 27              Nebraska                17.861790             75.308137
# 28                Nevada                21.157834             47.590271
# 29         New Hampshire                 7.364595             11.289900
# 30            New Jersey                17.608149             20.400450
# 31            New Mexico                34.015096             97.864162
# 32              New York                62.236091             34.058242
# 33        North Carolina                46.719349            169.199096
# 34          North Dakota                22.179741             48.088673
# 35                  Ohio                60.206429             93.304851
# 36              Oklahoma                32.165567            120.959138
# 37                Oregon                25.213369             56.396920
# 38          Pennsylvania                67.626463             88.264847
# 39          Rhode Island                 2.329942              3.159850
# 40        South Carolina                27.519354             83.499297
# 41          South Dakota                24.230483             60.368561
# 42             Tennessee                39.884096            103.150460
# 43                 Texas               136.621097            342.997099
# 44                  Utah                32.848235             41.208164
# 45               Vermont                10.290896             11.168420
# 46              Virginia                39.887094            129.239570
# 47            Washington                27.787410             42.284000
# 48         West Virginia                20.043454             45.305912
# 49             Wisconsin                36.970406             75.422835
# 50               Wyoming                34.530100             93.533848

# %%
interstates = 0
highways = 0

# %%
import os

# %%
state_list = os.listdir('resources/non_freeway_roads/')
output_roads = {}

for i in state_list:
    state_df = pd.read_csv(f'resources/non_freeway_roads/{i}')
    x = get_distance(state_df)
    output_roads[i] = sum(x['distance'].to_list())

# %%
output_roads
# Out:
# {'Alabama.csv': 2055.135931194679,
#  'Arizona.csv': 1519.7984156635687,
#  'Arkansas.csv': 2121.400731771309,
#  'California.csv': 4664.484636791149,
#  'Colorado.csv': 2022.606169492029,
#  'Connecticut.csv': 471.5694659920096,
#  'Delaware.csv': 207.43820151965093,
#  'District of Columbia.csv': 20.552629329131445,
#  'Florida.csv': 3012.1234482669915,
#  'Georgia.csv': 2834.4342016233795,
#  'Idaho.csv': 1357.0589522259213,
#  'Illinois.csv': 3681.51476596439,
#  'Indiana.csv': 2334.126738551404,
#  'Iowa.csv': 2584.541829049201,
#  'Kansas.csv': 2679.244407619301,
#  'Kentucky.csv': 1836.979655093898,
#  'Louisiana.csv': 1500.6627517453533,
#  'Maine.csv': 801.0856432381745,
#  'Maryland.csv': 766.1900308220053,
#  'Massachusetts.csv': 792.1449440759625,
#  'Michigan.csv': 2920.103706889421,
#  'Minnesota.csv': 3573.569155748913,
#  'Mississippi.csv': 1485.9789789526515,
#  'Missouri.csv': 3062.896296461078,
#  'Montana.csv': 1719.021094631166,
#  'Nebraska.csv': 1821.2372447477753,
#  'Nevada.csv': 615.1291338014304,
#  'New Hampshire.csv': 418.82497452927544,
#  'New Jersey.csv': 853.6639498877148,
#  'New Mexico.csv': 1366.9420236543508,
#  'New York.csv': 2732.0064907429028,
#  'North Carolina.csv': 3292.897004503628,
#  'North Dakota.csv': 2015.0358000585718,
#  'Ohio.csv': 3310.2760581543034,
#  'Oklahoma.csv': 2642.614751171473,
#  'Oregon.csv': 2175.869364057362,
#  'Pennsylvania.csv': 3492.89370564309,
#  'Rhode Island.csv': 124.50052744793456,
#  'South Carolina.csv': 1870.5355414924559,
#  'South Dakota.csv': 1730.3427159773753,
#  'Tennessee.csv': 2056.1446342576737,
#  'Texas.csv': 6344.794392483669,
#  'Utah.csv': 1021.3046564180958,
#  'Vermont.csv': 318.5638470709793,
#  'Virginia.csv': 2432.871492002197,
#  'Washington.csv': 2075.0320013331916,
#  'West Virginia.csv': 1313.4688099283867,
#  'Wisconsin.csv': 2549.928178542043,
#  'Wyoming.csv': 836.8554395621}

# %%
all_other_roads = pd.DataFrame({'state_name':[i.replace('.csv','') for i in output_roads.keys()], 'sum_other_distance':output_roads.values()})
all_other_roads.head()
# Out:
#    state_name  sum_other_distance
# 0     Alabama         2055.135931
# 1     Arizona         1519.798416
# 2    Arkansas         2121.400732
# 3  California         4664.484637
# 4    Colorado         2022.606169

# %%
distance_by_state = distance_by_state.merge(all_other_roads, how ='left', on='state_name').dropna()
distance_by_state
# Out:
